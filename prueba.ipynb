# %%
import pandas as pd
import numpy as np
import os

# %%
data = os.path.join("data", "Coffe_sales.xlsx")
df = pd.read_excel(data)
df
# Out:
#            date                datetime  hour_of_day cash_type  \
# 0    2024-03-01 2024-03-01 10:15:50.520           10      card
# 1    2024-03-01 2024-03-01 12:19:22.539           12      card
# 2    2024-03-01 2024-03-01 12:20:18.089           12      card
# 3    2024-03-01 2024-03-01 13:46:33.006           13      card
# 4    2024-03-01 2024-03-01 13:48:14.626           13      card
# ...         ...                     ...          ...       ...
# 3631 2025-03-23 2025-03-23 10:34:54.894           10      card
# 3632 2025-03-23 2025-03-23 14:43:37.362           14      card
# 3633 2025-03-23 2025-03-23 14:44:16.864           14      card
# 3634 2025-03-23 2025-03-23 15:47:28.723           15      card
# 3635 2025-03-23 2025-03-23 18:11:38.635           18      card
#
#                      card  money    coffee_name Time_of_Day Weekday  \
# 0     ANON-0000-0000-0001  38.70          Latte     Morning     Fri
# 1     ANON-0000-0000-0002  38.70  Hot Chocolate   Afternoon     Fri
# ...

# %%
#ver tipos de datos
df.dtypes
# Out:
# date           datetime64[ns]
# datetime       datetime64[ns]
# hour_of_day             int64
# cash_type              object
# card                   object
# money                 float64
# coffee_name            object
# Time_of_Day            object
# Weekday                object
# Month_name             object
# Weekdaysort             int64
# Monthsort               int64
# dtype: object

# %%
print(df.isna().sum())
print(df.describe())
# Out:
# date            0
# datetime        0
# hour_of_day     0
# cash_type       0
# card           89
# money           0
# coffee_name     0
# Time_of_Day     0
# Weekday         0
# Month_name      0
# Weekdaysort     0
# Monthsort       0
# dtype: int64
#                                 date                       datetime  \
# count                           3636                           3636
# mean   2024-09-30 11:56:02.376237568  2024-10-01 02:35:30.535053568
# min              2024-03-01 00:00:00     2024-03-01 10:15:50.520000
# 25%              2024-07-03 00:00:00  2024-07-03 16:54:06.084750080
# 50%              2024-10-06 12:00:00  2024-10-07 02:55:12.649500160
# 75%              2025-01-08 00:00:00  2025-01-08 07:55:20.299750144
# max              2025-03-23 00:00:00     2025-03-23 18:11:38.635000
# std                              NaN                            NaN
#
#        hour_of_day        money  Weekdaysort    Monthsort
# ...

# %%
for col in ["coffee_name", "cash_type", "Time_of_Day", "Weekday", "Month_name"]:
    print(f"{col}: {df[col].nunique()} valores únicos → {df[col].unique()[:10]}")
# Out:
# coffee_name: 8 valores únicos → ['Latte' 'Hot Chocolate' 'Americano' 'Americano with Milk' 'Cocoa'
#  'Cortado' 'Espresso' 'Cappuccino']
# cash_type: 2 valores únicos → ['card' 'cash']
# Time_of_Day: 3 valores únicos → ['Morning' 'Afternoon' 'Night']
# Weekday: 7 valores únicos → ['Fri' 'Sat' 'Sun' 'Mon' 'Tue' 'Wed' 'Thu']
# Month_name: 12 valores únicos → ['Mar' 'Apr' 'May' 'Jun' 'Jul' 'Aug' 'Sep' 'Oct' 'Nov' 'Dec']

# %%
#sacamos el total de ventas 
total = df["money"].sum()
avg = df["money"].mean()

transacciones = df.shape[0]

top5 = df.groupby("coffee_name")["money"].sum().sort_values(ascending=False).head(5)
ventas_dia = df.groupby("Weekday")["money"].sum().reset_index()
ventas_hora = df.groupby("Time_of_Day")["money"].sum().reset_index()
